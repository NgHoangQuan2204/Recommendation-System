# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random

# %%
df = pd.read_csv("../data/processed/movie_data_processed.csv", index_col= False)
df["Year"] = df["Year"].fillna("Unknown")
df.head(3)
# Out:
#                       Title        Year  Rated  Runtime  \
# 0              Breaking Bad     Unknown  TV-MA   49 min
# 1  The Shawshank Redemption  1994-01-01      R  142 min
# 2          Band of Brothers  2001-01-01  TV-MA  594 min
#
#                     Genre        Director                        Writer  \
# 0  Crime, Drama, Thriller         Unknown                Vince Gilligan
# 1                   Drama  Frank Darabont  Stephen King, Frank Darabont
# 2     Drama, History, War         Unknown                       Unknown
#
#                                        Actors  \
# 0       Bryan Cranston, Aaron Paul, Anna Gunn
# 1     Tim Robbins, Morgan Freeman, Bob Gunton
# 2  Scott Grimes, Damian Lewis, Ron Livingston
#
#                                                 Plot  \
# 0  A chemistry teacher diagnosed with inoperable ...
# 1  A banker convicted of uxoricide forms a friend...
# 2  The story of Easy Company of the U.S. Army 101...
#
#                                      Language                        Country  \
# 0                            English, Spanish                  United States
# 1                                     English                  United States
# 2  English, Dutch, French, German, Lithuanian  United Kingdom, United States
#
#                                               Awards  \
# 0  Won 16 Primetime Emmys. 169 wins & 269 nominat...
# 1  Nominated for 7 Oscars. 21 wins & 42 nominatio...
# 2  Won 6 Primetime Emmys. 34 wins & 26 nomination...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMzU5ZG...
# 1  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 2  https://m.media-amazon.com/images/M/MV5BMTQ3NT...
#
#                                              Ratings  imdbRating  imdbVotes  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...         9.5    2225876
# 1  [{'Source': 'Internet Movie Database', 'Value'...         9.3    2945396
# 2  [{'Source': 'Internet Movie Database', 'Value'...         9.4     542582
#
#       imdbID     BoxOffice    Status        wr
# 0  tt0903747       Unknown  Finished  9.464575
# 1  tt0111161  $28,767,189   Finished  9.274599
# 2  tt0185906       Unknown  Finished  9.262584

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6548 entries, 0 to 6547
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       6548 non-null   object
#  1   Year        6548 non-null   object
#  2   Rated       6548 non-null   object
#  3   Runtime     6548 non-null   object
#  4   Genre       6548 non-null   object
#  5   Director    6548 non-null   object
#  6   Writer      6548 non-null   object
#  7   Actors      6548 non-null   object
#  8   Plot        6548 non-null   object
#  9   Language    6548 non-null   object
#  10  Country     6548 non-null   object
#  11  Awards      6548 non-null   object
#  12  Poster      6548 non-null   object
#  13  Ratings     6548 non-null   object
#  14  imdbRating  6548 non-null   float64
#  15  imdbVotes   6548 non-null   int64
#  16  imdbID      6548 non-null   object
#  17  BoxOffice   6548 non-null   object
#  18  Status      6548 non-null   object
#  19  wr          6548 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 1023.3+ KB

# %% [markdown]
# # 1. Simple Recommender
#
# > Make general recommendations to all users, based on popularity and/or genre. The basic idea behind this system is that more popular and critically acclaimed movies are more likely to be liked by the average audience. An example might be the IMDB Top 250

# %%
def get_simple_recommendations(df, value, collumn):
    # Lọc các dòng chứa genre
    filtered_df = df[df[collumn].str.contains(value, na=False)]
    
    # Sắp xếp theo trọng số và lấy top 250
    filtered_df = filtered_df.sort_values('wr', ascending=False).head(10)
    
    return filtered_df[['Title', 'Year', 'Genre','imdbVotes', 'imdbRating', collumn]]

# %%
result = get_simple_recommendations(df, 'Action', "Genre")
result.head(10)
# Out:
#                                                 Title        Year  \
# 4                                     Game of Thrones     Unknown
# 7                          Avatar: The Last Airbender     Unknown
# 13                                    The Dark Knight  2008-01-01
# 14                                    Attack on Titan     Unknown
# 15      The Lord of the Rings: The Return of the King  2003-01-01
# 22  The Lord of the Rings: The Fellowship of the Ring  2001-01-01
# 26                   Fullmetal Alchemist: Brotherhood     Unknown
# 27                                             Arcane     Unknown
# 28                                          Inception  2010-01-01
# 31              The Lord of the Rings: The Two Towers  2002-01-01
#
#                            Genre  imdbVotes  imdbRating  \
# 4       Action, Adventure, Drama    2359163         9.2
# 7   Animation, Action, Adventure     386757         9.3
# 13          Action, Crime, Drama    2919777         9.0
# 14  Animation, Action, Adventure     551083         9.1
# 15      Action, Adventure, Drama    2015572         9.0
# 22      Action, Adventure, Drama    2045291         8.9
# 26  Animation, Action, Adventure     205897         9.1
# 27  Animation, Action, Adventure     293759         9.0
# 28     Action, Adventure, Sci-Fi    2592712         8.8
# 31      Action, Adventure, Drama    1819421         8.8
#
#                            Genre
# 4       Action, Adventure, Drama
# 7   Animation, Action, Adventure
# 13          Action, Crime, Drama
# 14  Animation, Action, Adventure
# 15      Action, Adventure, Drama
# 22      Action, Adventure, Drama
# 26  Animation, Action, Adventure
# 27  Animation, Action, Adventure
# 28     Action, Adventure, Sci-Fi
# 31      Action, Adventure, Drama

# %%
result = get_simple_recommendations(df, 'Stephen King', "Writer")
result.head(10)
# Out:
#                          Title        Year                     Genre  \
# 1     The Shawshank Redemption  1994-01-01                     Drama
# 59              The Green Mile  1999-01-01     Crime, Drama, Fantasy
# 125                The Shining  1980-01-01             Drama, Horror
# 330                Stand by Me  1986-01-01  Adventure, Comedy, Drama
# 700                     Misery  1990-01-01           Drama, Thriller
# 1485                    Carrie  1976-01-01           Horror, Mystery
# 1726              Doctor Sleep  2019-01-01    Drama, Fantasy, Horror
# 2160                  The Mist  2007-01-01  Horror, Sci-Fi, Thriller
# 2585         Dolores Claiborne  1995-01-01     Crime, Drama, Mystery
# 2619             The Dead Zone  1983-01-01     Drama, Horror, Sci-Fi
#
#       imdbVotes  imdbRating                                        Writer
# 1       2945396         9.3                  Stephen King, Frank Darabont
# 59      1433920         8.6                  Stephen King, Frank Darabont
# 125     1126290         8.4  Stephen King, Stanley Kubrick, Diane Johnson
# 330      450642         8.1  Stephen King, Raynold Gideon, Bruce A. Evans
# 700      240915         7.8                 Stephen King, William Goldman
# 1485     210615         7.4               Stephen King, Lawrence D. Cohen
# 1726     224755         7.3                   Mike Flanagan, Stephen King
# 2160     349565         7.1                  Frank Darabont, Stephen King
# 2585      49323         7.4                     Stephen King, Tony Gilroy
# 2619      79060         7.2                    Stephen King, Jeffrey Boam

# %% [markdown]
# # 2. Content based

# %% [markdown]
# > For the content-based method, the system will evaluate the characteristics of the recommended items. It will suggest items based on the user's profile or based on the content and attributes of items similar to the item the user has selected.
#
# For example, when the user watches the movie **The Shawshank Redemption**, the system will recommend the movie **The Green Mile**, which is in the same **Drama** genre or writer **Stephen King** as the movie the user likes.
#
# &rarr; Therefore, the system only needs to know which movie the user watches, not the ratings data, which helps it work even when the user does not have the habit of rating movies. And of course, it only recommends movies with similar characteristics, not a variety of movies or movies that are highly rated by the movie-watching community.

# %%
tf = TfidfVectorizer(analyzer='word', stop_words='english')
tfidf_matrix = tf.fit_transform(df['Plot'])

# %%
tfidf_matrix.shape
# Out:
# (6548, 16163)

# %%
# def computeCosineSimilarity(word_matrix):
#     cosine_similarity = linear_kernel(word_matrix, word_matrix)
#     return cosine_similarity

# %%
def computePearsonCorrelation(word_matrix):
    return np.corrcoef(word_matrix)

# %%
indices = pd.Series(df.index, index=df['Title'])
indices
# Out:
# Title
# Breaking Bad                   0
# The Shawshank Redemption       1
# Band of Brothers               2
# Chernobyl                      3
# Game of Thrones                4
#                             ...
# Bounce                      6543
# Mine                        6544
# Drive Me Crazy              6545
# Suspect Zero                6546
# The Reef                    6547
# Length: 6548, dtype: int64

# %%
def get_content_based_recommendations(movie_title, similarity_scores):
    # Fetch index of movie based on given title
    movie_idx = indices[movie_title]
    
    # Fetch similarity score of all movies with the given movie
    # Fetch it as a tuple of (index, score)
    similarity_scores = list(enumerate(similarity_scores[movie_idx]))
    
    # Sort the above score
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    
    # Pick index and score of 10 most similar movies
    # Skip the 0th index since it is same movie (itself)
    similarity_scores = similarity_scores[1:11]
    
    # Find the indices of these similar movies
    movie_similar_indices = [i[0] for i in similarity_scores]
    
    # Find title of these top movies and return
    return df.iloc[movie_similar_indices][['Title', 'imdbID', 'Year', 'Genre','imdbVotes', 'imdbRating', 'wr']].sort_values(by='wr', ascending=False)

# %%
similarity = cosine_similarity(tfidf_matrix)

# %%
get_content_based_recommendations('The Dark Knight', similarity)
# Out:
#                          Title      imdbID        Year  \
# 207              Batman Begins   tt0372784  2005-01-01
# 219          Kill Bill: Vol. 1   tt0266697  2003-01-01
# 562                 The Batman   tt1877830  2022-01-01
# 697                     Gotham   tt3749900     Unknown
# 716                The Penguin  tt15435876  2024-01-01
# 1112                    Batman   tt0096895  1989-01-01
# 2178            Batman Returns   tt0103776  1992-01-01
# 5145  Batman: The Killing Joke   tt4853102  2016-01-01
# 6230                     Becky  tt10314450  2020-01-01
# 6303                    Domino   tt0421054  2005-01-01
#
#                          Genre  imdbVotes  imdbRating        wr
# 207       Action, Crime, Drama    1601743         8.2  8.167970
# 219    Action, Crime, Thriller    1214597         8.2  8.157936
# 562       Action, Crime, Drama     828211         7.8  7.748807
# 697       Action, Crime, Drama     243328         7.8  7.635636
# 716      Crime, Drama, Fantasy      33845         8.8  7.624992
# 1112         Action, Adventure     412616         7.5  7.414460
# 2178    Action, Crime, Fantasy     332740         7.1  7.019165
# 5145  Animation, Action, Crime      62497         6.4  6.235893
# 6230      Action, Crime, Drama      25862         6.0  5.888669
# 6303  Action, Biography, Crime      69894         5.9  5.865767

# %%
tags_df = pd.read_csv('../data/processed/tags_processed.csv')

# %%
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724905 entries, 0 to 724904
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   userId   724905 non-null  int64
#  1   movieId  724905 non-null  int64
#  2   tag      724905 non-null  object
#  3   imdbId   724905 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 22.1+ MB

# %%
tags_grouped = tags_df.groupby('imdbId')['tag'].apply(list).reset_index()
del tags_df
tags_grouped.rename(columns={"imdbId": "imdbID"}, inplace=True)
tags_grouped
# Out:
#          imdbID                                                tag
# 0     tt0000417  [classic, experimental, sci-fi, black and whit...
# 1     tt0000439  [less than 300 ratings, not available from Net...
# 2     tt0004972  [racism, Racist, Racist History, racist, contr...
# 3     tt0010323  [german expressionism, psychology, serial kill...
# 4     tt0012349  [Tumey's DVDs, charity, orphan, poverty, silen...
# ...         ...                                                ...
# 5766  tt9806192  [animation, beautiful, cinematography, dreamli...
# 5767  tt9812474  [grief, atmospheric, fantasy, A24, atmospheric...
# 5768  tt9845564  [convoy, rapist, revenge, trapped inside, winter]
# 5769  tt9873892    [cheesy, cliche, Black, Blaxploitation, satire]
# 5770  tt9893250  [capitalism, dark comedy, Dianne Wiest, mafia,...
#
# [5771 rows x 2 columns]

# %%
df = df.merge(tags_grouped, on='imdbID', how='left')
df.head(1)
# Out:
#           Title     Year  Rated Runtime                   Genre Director  \
# 0  Breaking Bad  Unknown  TV-MA  49 min  Crime, Drama, Thriller  Unknown
#
#            Writer                                 Actors  \
# 0  Vince Gilligan  Bryan Cranston, Aaron Paul, Anna Gunn
#
#                                                 Plot          Language  ...  \
# 0  A chemistry teacher diagnosed with inoperable ...  English, Spanish  ...
#
#                                               Awards  \
# 0  Won 16 Primetime Emmys. 169 wins & 269 nominat...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMzU5ZG...
#
#                                              Ratings imdbRating  imdbVotes  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...        9.5    2225876
#
#       imdbID BoxOffice    Status        wr  tag
# 0  tt0903747   Unknown  Finished  9.464575  NaN
#
# [1 rows x 21 columns]

# %%
tag_counts = df.apply(lambda x: pd.Series(x['tag']),axis=1).stack().reset_index(level=1, drop=True)
tag_counts.name = 'tag'

# %%
tag_counts = tag_counts.value_counts()
tag_counts[:5]
# Out:
# tag
# sci-fi         4621
# atmospheric    4167
# action         3804
# funny          3314
# comedy         3201
# Name: count, dtype: int64

# %%
tag_counts = tag_counts[tag_counts > 1]

# %%
def filter_tags(x):
    words = []
    for i in x:
        if i in tag_counts:
            words.append(i)
    return words

# %%
df["tag"] = df["tag"].fillna('')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6548 entries, 0 to 6547
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       6548 non-null   object
#  1   Year        6548 non-null   object
#  2   Rated       6548 non-null   object
#  3   Runtime     6548 non-null   object
#  4   Genre       6548 non-null   object
#  5   Director    6548 non-null   object
#  6   Writer      6548 non-null   object
#  7   Actors      6548 non-null   object
#  8   Plot        6548 non-null   object
#  9   Language    6548 non-null   object
#  10  Country     6548 non-null   object
#  11  Awards      6548 non-null   object
#  12  Poster      6548 non-null   object
#  13  Ratings     6548 non-null   object
#  14  imdbRating  6548 non-null   float64
#  15  imdbVotes   6548 non-null   int64
#  16  imdbID      6548 non-null   object
#  17  BoxOffice   6548 non-null   object
#  18  Status      6548 non-null   object
#  19  wr          6548 non-null   float64
#  20  tag         6548 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.0+ MB

# %%
reco_features = ['Title', 'Director', 'Actors', 'tag', 'Genre']

# %%
def cleanUpData(data):
    if isinstance(data, list):
        return [str.lower(val.replace(" ", "")) for val in data]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(data, str):
            return str.lower(data.replace(" ", ""))
        else:
            return ''

# %%
# Apply data cleanup to reco features
modified_features = ['Director', 'Actors', 'tag', 'Genre']

for feature in modified_features:
    df[feature] = df[feature].apply(cleanUpData)
    
df[reco_features].head(5)
# Out:
#                       Title       Director  \
# 0              Breaking Bad        unknown
# 1  The Shawshank Redemption  frankdarabont
# 2          Band of Brothers        unknown
# 3                 Chernobyl        unknown
# 4           Game of Thrones        unknown
#
#                                        Actors  \
# 0            bryancranston,aaronpaul,annagunn
# 1          timrobbins,morganfreeman,bobgunton
# 2       scottgrimes,damianlewis,ronlivingston
# 3  jessiebuckley,jaredharris,stellanskarsgård
# 4     emiliaclarke,peterdinklage,kitharington
#
#                                                  tag                   Genre
# 0                                                       crime,drama,thriller
# 1  [basedonabook, morganfreeman, twistending, fri...                   drama
# 2  [accurate, gritty, war, worldwarii, notamovie,...       drama,history,war
# 3                                                     drama,history,thriller
# 4                                                     action,adventure,drama

# %%
# Chuyển đổi các cột thành danh sách
df['Director'] = df['Director'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
df['Actors'] = df['Actors'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
df['Genre'] = df['Genre'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
df[reco_features].head(1)
# Out:
#           Title   Director                                Actors tag  \
# 0  Breaking Bad  [unknown]  [bryancranston, aaronpaul, annagunn]
#
#                       Genre
# 0  [crime, drama, thriller]

# %%
def createSoup(data):
    # Loại bỏ trùng lặp trong mỗi danh sách trước khi nối
    director = ' '.join(data['Director'])
    actors = ' '.join(data['Actors'])
    tag = ' '.join(set(data['tag']))  # Dùng set để loại bỏ trùng lặp
    genre = ' '.join(data['Genre'])
    
    # Ghép tất cả lại thành chuỗi duy nhất
    return f"{director} {actors} {tag} {genre}"

createSoup(df.iloc[0,:])
# Out:
# 'unknown bryancranston aaronpaul annagunn  crime drama thriller'

# %%
# Create a new feature Soup with mixed data
df['soup'] = df.apply(createSoup, axis=1)

reco_features = ['Title', 'Director', 'Actors', 'tag', 'Genre', 'soup']
df[reco_features].head(5)
# Out:
#                       Title         Director  \
# 0              Breaking Bad        [unknown]
# 1  The Shawshank Redemption  [frankdarabont]
# 2          Band of Brothers        [unknown]
# 3                 Chernobyl        [unknown]
# 4           Game of Thrones        [unknown]
#
#                                            Actors  \
# 0            [bryancranston, aaronpaul, annagunn]
# 1          [timrobbins, morganfreeman, bobgunton]
# 2       [scottgrimes, damianlewis, ronlivingston]
# 3  [jessiebuckley, jaredharris, stellanskarsgård]
# 4     [emiliaclarke, peterdinklage, kitharington]
#
#                                                  tag  \
# 0
# 1  [basedonabook, morganfreeman, twistending, fri...
# 2  [accurate, gritty, war, worldwarii, notamovie,...
# 3
# 4
#
#                         Genre  \
# 0    [crime, drama, thriller]
# 1                     [drama]
# 2       [drama, history, war]
# 3  [drama, history, thriller]
# 4  [action, adventure, drama]
#
#                                                 soup
# 0  unknown bryancranston aaronpaul annagunn  crim...
# 1  frankdarabont timrobbins morganfreeman bobgunt...
# 2  unknown scottgrimes damianlewis ronlivingston ...
# 3  unknown jessiebuckley jaredharris stellanskars...
# 4  unknown emiliaclarke peterdinklage kitharingto...

# %%
# Define a CountVectorizer Object
cntVec = CountVectorizer(stop_words='english')

# Remove NaN from soup with empty strings
df['soup'] = df['soup'].fillna('')

# Construct CountVectorizer matrix by fitting and transforming the data
cntVec_matrix = cntVec.fit_transform(df['soup'])

print("Shape of CountVectorizer matrix =", cntVec_matrix.shape)

# Topmost frequently occuring words
words = cntVec.get_feature_names_out()
counts = cntVec_matrix.sum(axis=0).reshape(-1,1).tolist()
print("Most frequently occuring words in plot overview:")
word_count = dict(sorted(zip(words, counts), key=lambda x : x[1], reverse=True)[:20])
print(word_count)
# Out:
# Shape of CountVectorizer matrix = (6548, 73221)
# Most frequently occuring words in plot overview:
# {'drama': [4338], 'comedy': [2963], 'action': [2336], 'crime': [1767], 'romance': [1556], 'adventure': [1545], 'thriller': [1347], 'nudity': [1113], 'mystery': [990], 'horror': [897], 'fi': [872], 'unknown': [857], 'sci': [856], 'murder': [853], 'violence': [801], 'fantasy': [753], 'funny': [704], 'animation': [701], 'sdvds': [678], 'biography': [677]}

# %%
# Find recommendations based on Cosine Similarity
similarity = cosine_similarity(cntVec_matrix)
get_content_based_recommendations('Spectre', similarity)
# Out:
#                                    Title      imdbID        Year  \
# 569                              Skyfall   tt1074638  2012-01-01
# 756        Mission: Impossible - Fallout   tt4912910  2018-01-01
# 1329  Mission: Impossible - Rogue Nation   tt2381249  2015-01-01
# 1540                      No Time to Die   tt2382320  2021-01-01
# 2774                       Extraction II  tt12263384  2023-01-01
# 3964                        Jason Bourne   tt4196776  2016-01-01
# 4685                               Plane   tt5884796  2023-01-01
# 5224                                 War   tt7430722  2019-01-01
# 5817                             Copshop   tt5748448  2021-01-01
# 6268                       Power Rangers   tt3717490  2017-01-01
#
#                               Genre  imdbVotes  imdbRating        wr
# 569   [action, adventure, thriller]     739511         7.8  7.742838
# 756   [action, adventure, thriller]     385191         7.7  7.598233
# 1329  [action, adventure, thriller]     416465         7.4  7.320066
# 1540  [action, adventure, thriller]     453414         7.3  7.230764
# 2774      [action, crime, thriller]     155496         7.0  6.850120
# 3964             [action, thriller]     245974         6.6  6.532670
# 4685  [action, adventure, thriller]      84481         6.5  6.349922
# 5224  [action, adventure, thriller]      34154         6.5  6.213585
# 5817             [action, thriller]      40435         6.2  6.046084
# 6268   [action, adventure, fantasy]     115015         5.9  5.877103

# %% [markdown]
# # 3. Item-based Collaborative Filtering

# %% [markdown]
# - Based on user's ratings, we create an interaction matrix between user rating and movies, which then we can use to compute correlation between movies,
#  then we filter out 10 movies with highest correlation coefficient.

# %%
df_ratings = pd.read_csv('../data/processed/ratings_processed.csv')
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201140 entries, 0 to 21201139
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   userId  int64
#  1   rating  float64
#  2   imdbID  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 485.3+ MB

# %%
df_ratings = df_ratings.merge(df[['imdbID', 'Title']], on= 'imdbID', how= 'inner')

df_ratings.head()
# Out:
#    userId  rating     imdbID                  Title
# 0       1     8.0  tt0114388  Sense and Sensibility
# 1       3    10.0  tt0114388  Sense and Sensibility
# 2      15     9.0  tt0114388  Sense and Sensibility
# 3      28     8.0  tt0114388  Sense and Sensibility
# 4      29     8.0  tt0114388  Sense and Sensibility

# %%
# Create User-Item interaction matrix
matrix = df_ratings.pivot_table(index='userId', columns='Title', values='rating')

# Free memory
del df_ratings

matrix.head()
# Out:
# Title   10 Cloverfield Lane  10 Things I Hate About You  12 Angry Men  \
# userId
# 1                       NaN                         NaN          10.0
# 2                       NaN                         NaN           NaN
# 3                       NaN                         NaN           NaN
# 4                       NaN                         NaN           NaN
# 5                       NaN                         NaN           NaN
#
# Title   12 Monkeys  12 Years a Slave  127 Hours  13 Going on 30  1408  1917  \
# userId
# 1             10.0               NaN        NaN             NaN   NaN   NaN
# 2              NaN               NaN        NaN             NaN   NaN   NaN
# 3              NaN               NaN        NaN             NaN   NaN   NaN
# 4              NaN               NaN        NaN             NaN   NaN   NaN
# 5              NaN               NaN        NaN             NaN   NaN   NaN
#
# Title   2 Fast 2 Furious  ...  You've Got Mail  Young Frankenstein  \
# userId                    ...
# 1                    NaN  ...              2.0                 NaN
# 2                    NaN  ...              NaN                 NaN
# 3                    NaN  ...              NaN                 NaN
# 4                    NaN  ...              NaN                 NaN
# 5                    NaN  ...              NaN                 NaN
#
# Title   Young Guns  Zero Dark Thirty  Zodiac  Zombieland  Zoolander  Zootopia  \
# userId
# 1              NaN               NaN     NaN         NaN        NaN       NaN
# 2              NaN               NaN     NaN         NaN        NaN       NaN
# 3              NaN               NaN     NaN         NaN        NaN       NaN
# 4              NaN               NaN     NaN         NaN        NaN       NaN
# 5              NaN               NaN     NaN         NaN        NaN       NaN
#
# Title   eXistenZ  xXx
# userId
# 1            NaN  NaN
# 2            NaN  NaN
# 3            NaN  NaN
# 4            4.0  NaN
# 5            NaN  NaN
#
# [5 rows x 1394 columns]

# %%
def get_collaborative_filtering_recommendations(movie):
    
    # Fetch ratings for movie
    movie_user_rating = matrix[movie]

    # Find correlation between movies
    similar_to_movie= matrix.corrwith(movie_user_rating)

    # Getting correlated movies
    corr_movies = pd.DataFrame(similar_to_movie, columns=['Correlation'])
    corr_movies = corr_movies.sort_values(by='Correlation', ascending=False)
    
    corr_movies_indeces = corr_movies[1:11].index
    
    return df[df['Title'].isin(corr_movies_indeces)][['Title', 'imdbID', 'Year', 'Genre','imdbVotes', 'imdbRating', 'wr']].sort_values(by='wr', ascending=False)

# %%
get_collaborative_filtering_recommendations('Spectre')
# Out:
#                                    Title     imdbID        Year  \
# 386                        Casino Royale  tt0381061  2006-01-01
# 569                              Skyfall  tt1074638  2012-01-01
# 1329  Mission: Impossible - Rogue Nation  tt2381249  2015-01-01
# 2813             Mission: Impossible III  tt0317919  2006-01-01
# 3856                    Live and Let Die  tt0070328  1973-01-01
# 4233                   Quantum of Solace  tt0830515  2008-01-01
# 4389                 Tomorrow Never Dies  tt0120347  1997-01-01
# 4557                Diamonds Are Forever  tt0066995  1971-01-01
# 4720             The World Is Not Enough  tt0143145  1999-01-01
# 5713                     Die Another Day  tt0246460  2002-01-01
#
#                               Genre  imdbVotes  imdbRating        wr
# 386   [action, adventure, thriller]     702997         8.0  7.934089
# 569   [action, adventure, thriller]     739511         7.8  7.742838
# 1329  [action, adventure, thriller]     416465         7.4  7.320066
# 2813  [action, adventure, thriller]     395751         6.9  6.841569
# 3856  [action, adventure, thriller]     116799         6.7  6.554277
# 4233   [action, adventure, mystery]     475392         6.5  6.468051
# 4389  [action, adventure, thriller]     206514         6.5  6.430333
# 4557  [action, adventure, thriller]     115496         6.5  6.383962
# 4720  [action, adventure, thriller]     211725         6.4  6.341011
# 5713  [action, adventure, thriller]     231107         6.1  6.070799

# %% [markdown]
# # 4. Weighted-Mixed Hybrid

# %% [markdown]
# - Weighted means movies are ranked based on weighted average score.
# - Mixed means we take both recommendations lists as the result.

# %%
def get_hybrid_recommendations(movie):
    content_based_recommends = get_content_based_recommendations(movie, similarity)
    collaborative_filtering_recommends = get_collaborative_filtering_recommendations(movie)
    
    # Combine 2 recommendations lists
    hybrid_recommends = pd.concat([content_based_recommends, collaborative_filtering_recommends], ignore_index=True) \
                            .sort_values(by='wr', ascending=False) \
                            .drop_duplicates(['Title'],ignore_index= True)
    
    return hybrid_recommends

# %%
get_hybrid_recommendations('Spectre')
# Out:
#                                  Title      imdbID        Year  \
# 0                        Casino Royale   tt0381061  2006-01-01
# 1                              Skyfall   tt1074638  2012-01-01
# 2        Mission: Impossible - Fallout   tt4912910  2018-01-01
# 3   Mission: Impossible - Rogue Nation   tt2381249  2015-01-01
# 4                       No Time to Die   tt2382320  2021-01-01
# 5                        Extraction II  tt12263384  2023-01-01
# 6              Mission: Impossible III   tt0317919  2006-01-01
# 7                     Live and Let Die   tt0070328  1973-01-01
# 8                         Jason Bourne   tt4196776  2016-01-01
# 9                    Quantum of Solace   tt0830515  2008-01-01
# 10                 Tomorrow Never Dies   tt0120347  1997-01-01
# 11                Diamonds Are Forever   tt0066995  1971-01-01
# 12                               Plane   tt5884796  2023-01-01
# 13             The World Is Not Enough   tt0143145  1999-01-01
# 14                                 War   tt7430722  2019-01-01
# 15                     Die Another Day   tt0246460  2002-01-01
# 16                             Copshop   tt5748448  2021-01-01
# 17                       Power Rangers   tt3717490  2017-01-01
#
#                             Genre  imdbVotes  imdbRating        wr
# 0   [action, adventure, thriller]     702997         8.0  7.934089
# 1   [action, adventure, thriller]     739511         7.8  7.742838
# 2   [action, adventure, thriller]     385191         7.7  7.598233
# 3   [action, adventure, thriller]     416465         7.4  7.320066
# 4   [action, adventure, thriller]     453414         7.3  7.230764
# 5       [action, crime, thriller]     155496         7.0  6.850120
# 6   [action, adventure, thriller]     395751         6.9  6.841569
# 7   [action, adventure, thriller]     116799         6.7  6.554277
# 8              [action, thriller]     245974         6.6  6.532670
# 9    [action, adventure, mystery]     475392         6.5  6.468051
# 10  [action, adventure, thriller]     206514         6.5  6.430333
# 11  [action, adventure, thriller]     115496         6.5  6.383962
# 12  [action, adventure, thriller]      84481         6.5  6.349922
# 13  [action, adventure, thriller]     211725         6.4  6.341011
# 14  [action, adventure, thriller]      34154         6.5  6.213585
# 15  [action, adventure, thriller]     231107         6.1  6.070799
# 16             [action, thriller]      40435         6.2  6.046084
# 17   [action, adventure, fantasy]     115015         5.9  5.877103

# %% [markdown]
# # 5. Evaluation Metric

# %% [markdown]
# - The code below is a metric that Netflix and Amazon uses for their recommendation system evaluation.
# - However, it is implemented for user-based recommender rather than item-based recommender because it requires user-oriented recommendations for the evaluation
# to be correct, not general opinions such as the result of item-based recommender.

# %%
# # Number of users to sample
# user_count = 10

# # Hit count, which represents accurate recommend attempts
# hit = 0

# for i in range(1, user_count + 1):
#     # Get user's unrated and rated movies
#     user_nan = matrix.columns[matrix[i-1:i].isna().any()].tolist()
#     user_rated = matrix.columns[matrix[i-1:i].notna().any()].tolist()
    
#     # Mixed 99 user-unrated sample with 1 user-rated sample
#     random_unrated = random.sample(user_nan, 99)
#     random_rated = random.sample(user_rated, 1)
#     test_titles = random_unrated + random_rated
    
#     # Run recommendation system on all of the sample title
#     all_recommends = pd.DataFrame()
#     for title in test_titles:
#         recommends = get_collaborative_filtering_recommendations(title)
#         all_recommends = pd.concat([all_recommends, recommends])

#     # Count occurences
#     counted_recommend = all_recommends.value_counts().reset_index(name='Counts')
    
#     # Get top 10 occurences in recommended list
#     top_10_occur = counted_recommend[0:10]
    
#     if test_titles[0] in top_10_occur['Title']:
#         hit += 1

# # Calculated hit ratio
# hit_ratio = hit / user_count
# print('Accuracy: ', hit_ratio)
