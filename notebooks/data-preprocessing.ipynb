# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("../data/raw/movie_data.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25936\1631465093.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/movie_data.csv")

# %%
df = df.drop_duplicates(keep='first')

df.head(5)
# Out:
#                          Title  Year     Rated   Released  Runtime  \
# 0            Good Neighbor Sam  1964  Approved  22-Jul-64  130 min
# 1  Eddie Izzard: Dress to Kill  1999   Unrated  13-Jun-99  115 min
# 2                    Quo Vadis  1951  Approved  25-Dec-51  171 min
# 3       The Captain's Paradise  1953  Approved  28-Sep-53   94 min
# 4                Batman Begins  2005     PG-13  15-Jun-05  140 min
#
#                        Genre                    Director  \
# 0                     Comedy                 David Swift
# 1        Documentary, Comedy             Lawrence Jordan
# 2  Biography, Drama, Romance  Mervyn LeRoy, Anthony Mann
# 3            Comedy, Romance             Anthony Kimmins
# 4       Action, Crime, Drama           Christopher Nolan
#
#                                            Writer  \
# 0  James Fritzell, Everett Greenbaum, David Swift
# 1                                    Eddie Izzard
# 2      John Lee Mahin, S.N. Behrman, Sonya Levien
# 3                    Alec Coppel, Nicholas Phipps
# 4     Bob Kane, David S. Goyer, Christopher Nolan
#
#                                          Actors  \
# 0  Jack Lemmon, Romy Schneider, Dorothy Provine
# 1                                  Eddie Izzard
# 2         Robert Taylor, Deborah Kerr, Leo Genn
# 3    Alec Guinness, Peter Bull, Charles Goldner
# 4   Christian Bale, Michael Caine, Ken Watanabe
#
#                                                 Plot  ...   Type  DVD  \
# 0  To help his divorced neighbor claim a substant...  ...  movie  NaN
# 1  Executive transvestite Eddie Izzard takes his ...  ...  movie  NaN
# 2  After fierce Roman commander Marcus Vinicius b...  ...  movie  NaN
# 3  The captain of a ferry boat between the restri...  ...  movie  NaN
# 4  After witnessing his parents' death, Bruce lea...  ...  movie  NaN
#
#        BoxOffice Production Website  Response  Season Episode seriesID  \
# 0    $9,072,726         NaN     NaN      True     NaN     NaN      NaN
# 1            NaN        NaN     NaN      True     NaN     NaN      NaN
# 2            NaN        NaN     NaN      True     NaN     NaN      NaN
# 3            NaN        NaN     NaN      True     NaN     NaN      NaN
# 4  $206,863,479         NaN     NaN      True     NaN     NaN      NaN
#
#   totalSeasons
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 29 columns]

# %%
df.drop(['Metascore', 'Type', 'DVD', 'Production', 'Website', 
         'Response','Season', 'totalSeasons','Episode', 'seriesID', 'Released'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76911 entries, 0 to 88513
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       76911 non-null  object
#  1   Year        76911 non-null  object
#  2   Rated       48818 non-null  object
#  3   Runtime     76363 non-null  object
#  4   Genre       76770 non-null  object
#  5   Director    76040 non-null  object
#  6   Writer      71444 non-null  object
#  7   Actors      75012 non-null  object
#  8   Plot        75806 non-null  object
#  9   Language    75112 non-null  object
#  10  Country     76540 non-null  object
#  11  Awards      41397 non-null  object
#  12  Poster      76338 non-null  object
#  13  Ratings     76911 non-null  object
#  14  imdbRating  75911 non-null  float64
#  15  imdbVotes   76698 non-null  object
#  16  imdbID      76911 non-null  object
#  17  BoxOffice   16629 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 11.1+ MB

# %%
df['Rated'] = df['Rated'].fillna('Unrated')
df['Runtime'] = df['Runtime'].fillna('Unknown')
df['Awards'] = df['Awards'].fillna('No award')
df['BoxOffice'] = df['BoxOffice'].fillna('Unknown')
df['Poster'] = df['Poster'].fillna('Not available')
df['Country'] = df['Country'].fillna('Unknown')
df['Language'] = df['Language'].fillna('Unknown')
df['Writer'] = df['Writer'].fillna('Unknown')
df['Director'] = df['Director'].fillna('Unknown')

df['Year'] = pd.to_datetime(df['Year'], format='%Y', errors='coerce')

# %%
df = df.dropna(subset=['Actors', 'Plot', 'Genre', 'imdbVotes', 'imdbRating'])

df['imdbVotes'] = df['imdbVotes'].replace(',', '', regex=True).fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73340 entries, 0 to 88513
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       73340 non-null  object
#  1   Year        73190 non-null  datetime64[ns]
#  2   Rated       73340 non-null  object
#  3   Runtime     73340 non-null  object
#  4   Genre       73340 non-null  object
#  5   Director    73340 non-null  object
#  6   Writer      73340 non-null  object
#  7   Actors      73340 non-null  object
#  8   Plot        73340 non-null  object
#  9   Language    73340 non-null  object
#  10  Country     73340 non-null  object
#  11  Awards      73340 non-null  object
#  12  Poster      73340 non-null  object
#  13  Ratings     73340 non-null  object
#  14  imdbRating  73340 non-null  float64
#  15  imdbVotes   73340 non-null  int32
#  16  imdbID      73340 non-null  object
#  17  BoxOffice   73340 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(15)
# memory usage: 10.4+ MB

# %%
df.describe()
# Out:
#                                 Year    imdbRating     imdbVotes
# count                          73190  73340.000000  7.334000e+04
# mean   1994-12-14 11:24:36.300041216      6.144179  1.466915e+04
# min              1878-01-01 00:00:00      1.000000  5.000000e+00
# 25%              1980-01-01 00:00:00      5.500000  3.880000e+02
# 50%              2005-01-01 00:00:00      6.300000  1.103000e+03
# 75%              2015-01-01 00:00:00      7.000000  3.979250e+03
# max              2023-01-01 00:00:00     10.000000  2.945396e+06
# std                              NaN      1.183479  7.372629e+04

# %%
rating = df[df['imdbRating'].notnull()]['imdbRating'].astype('int')
C = rating.mean()
C
# Out:
# 5.697995636760295

# %%
vote_count = df[df['imdbVotes'].notnull()]['imdbVotes'].astype('int')
m = vote_count.quantile(0.90)
m
# Out:
# 18962.300000000017

# %%
qualified = df[(df['imdbRating'] >= C) & (df['imdbVotes'] >= m)]
qualified.shape
# Out:
# (6406, 18)

# %%
def weighted_rating(x):
    v = x['imdbVotes']
    R = x['imdbRating']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Tạo một bản sao độc lập để tránh SettingWithCopyWarning
qualified = qualified.copy()

# Gán giá trị vào cột 'wr'
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# Sort
qualified = qualified.sort_values('wr', ascending=False)
# Out:
# (6406, 19)

# %%
qualified.head(5)
# Out:
#                           Title       Year  Rated  Runtime  \
# 75836  The Shawshank Redemption 1994-01-01      R  142 min
# 51648          Band of Brothers 2001-01-01  TV-MA  594 min
# 76362             The Godfather 1972-01-01      R  175 min
# 46533              Planet Earth 2006-01-01  TV-PG  538 min
# 51797           Planet Earth II 2016-01-01   TV-G  298 min
#
#                      Genre              Director  \
# 75836                Drama        Frank Darabont
# 51648  Drama, History, War               Unknown
# 76362         Crime, Drama  Francis Ford Coppola
# 46533  Documentary, Family               Unknown
# 51797          Documentary               Unknown
#
#                                  Writer  \
# 75836      Stephen King, Frank Darabont
# 51648                           Unknown
# 76362  Mario Puzo, Francis Ford Coppola
# 46533                           Unknown
# 51797                           Unknown
#
#                                                   Actors  \
# 75836            Tim Robbins, Morgan Freeman, Bob Gunton
# 51648         Scott Grimes, Damian Lewis, Ron Livingston
# 76362               Marlon Brando, Al Pacino, James Caan
# 46533  Sigourney Weaver, David Attenborough, Nikolay ...
# 51797  David Attenborough, Gordon Buchanan, Barrie Br...
#
#                                                     Plot  \
# 75836  A banker convicted of uxoricide forms a friend...
# 51648  The story of Easy Company of the U.S. Army 101...
# 76362  The aging patriarch of an organized crime dyna...
# 46533  A documentary series on the wildlife found on ...
# 51797  David Attenborough returns with a new wildlife...
#
#                                          Language  \
# 75836                                     English
# 51648  English, Dutch, French, German, Lithuanian
# 76362                     English, Italian, Latin
# 46533                                     English
# 51797                             English, French
#
#                                                  Country  \
# 75836                                      United States
# 51648                      United Kingdom, United States
# 76362                                      United States
# 46533       United Kingdom, Canada, United States, Japan
# 51797  United Kingdom, Germany, France, China, United...
#
#                                                   Awards  \
# 75836  Nominated for 7 Oscars. 21 wins & 42 nominatio...
# 51648  Won 6 Primetime Emmys. 34 wins & 26 nomination...
# 76362       Won 3 Oscars. 31 wins & 31 nominations total
# 46533  Won 4 Primetime Emmys. 15 wins & 15 nomination...
# 51797  Won 2 Primetime Emmys. 15 wins & 28 nomination...
#
#                                                   Poster  \
# 75836  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 51648  https://m.media-amazon.com/images/M/MV5BMTQ3NT...
# 76362  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 46533  https://m.media-amazon.com/images/M/MV5BY2NjND...
# 51797  https://m.media-amazon.com/images/M/MV5BMzY4ND...
#
#                                                  Ratings  imdbRating  \
# 75836  [{'Source': 'Internet Movie Database', 'Value'...         9.3
# 51648  [{'Source': 'Internet Movie Database', 'Value'...         9.4
# 76362  [{'Source': 'Internet Movie Database', 'Value'...         9.2
# 46533  [{'Source': 'Internet Movie Database', 'Value'...         9.4
# 51797  [{'Source': 'Internet Movie Database', 'Value'...         9.5
#
#        imdbVotes     imdbID      BoxOffice        wr
# 75836    2945396  tt0111161   $28,767,189   9.276959
# 51648     542582  tt0185906        Unknown  9.274990
# 76362    2048917  tt0068646  $136,381,073   9.167887
# 46533     222764  tt0795176        Unknown  9.109595
# 51797     160979  tt5491994        Unknown  9.099343

# %%
s = qualified.apply(lambda x: pd.Series(x['Genre']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'Genre'
print(s)
gen_md = qualified.drop('Genre', axis=1).join(s)
# Out:
# 4            Action, Crime, Drama
# 9                  Drama, Romance
# 16       Horror, Sci-Fi, Thriller
# 24                  Comedy, Drama
# 26                         Horror
#                    ...
# 88361                       Drama
# 88385      Drama, Horror, Mystery
# 88392                  Drama, War
# 88485              Drama, Romance
# 88488      Action, Comedy, Horror
# Name: Genre, Length: 6406, dtype: object
