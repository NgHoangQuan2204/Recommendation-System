# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("../data/raw/full_movie_data.csv", index_col=False)

df.head(5)
# Out:
# C:\Users\kdat1\AppData\Local\Temp\ipykernel_3356\3480122303.py:1: DtypeWarning: Columns (23,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/full_movie_data.csv", index_col=False)
#                          Title  Year     Rated   Released  Runtime  \
# 0            Good Neighbor Sam  1964  Approved  22-Jul-64  130 min
# 1  Eddie Izzard: Dress to Kill  1999   Unrated  13-Jun-99  115 min
# 2                    Quo Vadis  1951  Approved  25-Dec-51  171 min
# 3       The Captain's Paradise  1953  Approved  28-Sep-53   94 min
# 4                Batman Begins  2005     PG-13  15-Jun-05  140 min
#
#                        Genre                    Director  \
# 0                     Comedy                 David Swift
# 1        Documentary, Comedy             Lawrence Jordan
# 2  Biography, Drama, Romance  Mervyn LeRoy, Anthony Mann
# 3            Comedy, Romance             Anthony Kimmins
# 4       Action, Crime, Drama           Christopher Nolan
#
#                                            Writer  \
# 0  James Fritzell, Everett Greenbaum, David Swift
# 1                                    Eddie Izzard
# 2      John Lee Mahin, S.N. Behrman, Sonya Levien
# 3                    Alec Coppel, Nicholas Phipps
# 4     Bob Kane, David S. Goyer, Christopher Nolan
#
#                                          Actors  \
# 0  Jack Lemmon, Romy Schneider, Dorothy Provine
# 1                                  Eddie Izzard
# 2         Robert Taylor, Deborah Kerr, Leo Genn
# 3    Alec Guinness, Peter Bull, Charles Goldner
# 4   Christian Bale, Michael Caine, Ken Watanabe
#
#                                                 Plot  ...  DVD      BoxOffice  \
# 0  To help his divorced neighbor claim a substant...  ...  NaN    $9,072,726
# 1  Executive transvestite Eddie Izzard takes his ...  ...  NaN            NaN
# 2  After fierce Roman commander Marcus Vinicius b...  ...  NaN            NaN
# 3  The captain of a ferry boat between the restri...  ...  NaN            NaN
# 4  After witnessing his parents' death, Bruce lea...  ...  NaN  $206,863,479
#
#   Production Website Response  Season  Episode seriesID totalSeasons    Status
# 0        NaN     NaN     True     NaN      NaN      NaN          NaN  Finished
# 1        NaN     NaN     True     NaN      NaN      NaN          NaN  Finished
# 2        NaN     NaN     True     NaN      NaN      NaN          NaN  Finished
# 3        NaN     NaN     True     NaN      NaN      NaN          NaN  Finished
# 4        NaN     NaN     True     NaN      NaN      NaN          NaN  Finished
#
# [5 rows x 30 columns]

# %%
df.drop(['Metascore', 'Type', 'DVD', 'Production', 'Website', 
         'Response','Season', 'totalSeasons','Episode', 'seriesID', 'Released'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73438 entries, 0 to 73437
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       73438 non-null  object
#  1   Year        73438 non-null  object
#  2   Rated       46902 non-null  object
#  3   Runtime     72085 non-null  object
#  4   Genre       73340 non-null  object
#  5   Director    69417 non-null  object
#  6   Writer      67123 non-null  object
#  7   Actors      71696 non-null  object
#  8   Plot        72385 non-null  object
#  9   Language    71834 non-null  object
#  10  Country     73143 non-null  object
#  11  Awards      39772 non-null  object
#  12  Poster      72915 non-null  object
#  13  Ratings     73438 non-null  object
#  14  imdbRating  72456 non-null  float64
#  15  imdbVotes   73245 non-null  object
#  16  imdbID      73438 non-null  object
#  17  BoxOffice   15045 non-null  object
#  18  Status      73438 non-null  object
# dtypes: float64(1), object(18)
# memory usage: 10.6+ MB

# %%
df['Rated'] = df['Rated'].fillna('Unrated')
df['Plot'] = df['Plot'].fillna('')
df['Year'] = df['Year'].fillna('Unknown')
df['Runtime'] = df['Runtime'].fillna('Unknown')
df['Awards'] = df['Awards'].fillna('No award')
df['BoxOffice'] = df['BoxOffice'].fillna('Unknown')
df['Poster'] = df['Poster'].fillna('Not available')
df['Country'] = df['Country'].fillna('Unknown')
df['Language'] = df['Language'].fillna('Unknown')
df['Writer'] = df['Writer'].fillna('Unknown')
df['Director'] = df['Director'].fillna('Unknown')

df['Year'] = pd.to_datetime(df['Year'], format='%Y', errors='coerce')

# %%
df = df.dropna(subset=['Actors', 'Plot', 'Genre', 'imdbVotes', 'imdbRating'])

df['imdbVotes'] = df['imdbVotes'].replace(',', '', regex=True).fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70790 entries, 0 to 73437
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       70790 non-null  object
#  1   Year        68020 non-null  datetime64[ns]
#  2   Rated       70790 non-null  object
#  3   Runtime     70790 non-null  object
#  4   Genre       70790 non-null  object
#  5   Director    70790 non-null  object
#  6   Writer      70790 non-null  object
#  7   Actors      70790 non-null  object
#  8   Plot        70790 non-null  object
#  9   Language    70790 non-null  object
#  10  Country     70790 non-null  object
#  11  Awards      70790 non-null  object
#  12  Poster      70790 non-null  object
#  13  Ratings     70790 non-null  object
#  14  imdbRating  70790 non-null  float64
#  15  imdbVotes   70790 non-null  int32
#  16  imdbID      70790 non-null  object
#  17  BoxOffice   70790 non-null  object
#  18  Status      70790 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(16)
# memory usage: 10.5+ MB

# %%
rating = df[df['imdbRating'].notnull()]['imdbRating'].astype('int')
C = rating.mean()
C
# Out:
# 5.761802514479446

# %%
vote_count = df[df['imdbVotes'].notnull()]['imdbVotes'].astype('int')
m = vote_count.quantile(0.9)
m
# Out:
# 20652.0

# %%
qualified = df[(df['imdbRating'] >= C) & (df['imdbVotes'] >= m)]
qualified.shape
# Out:
# (6190, 19)

# %%
def weighted_rating(x):
    v = x['imdbVotes']
    R = x['imdbRating']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
qualified = qualified.copy()

# Gán giá trị vào cột 'wr'
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# Sort
qualified = qualified.sort_values('wr', ascending=False)

# %%
qualified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6190 entries, 69608 to 4546
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       6190 non-null   object
#  1   Year        5417 non-null   datetime64[ns]
#  2   Rated       6190 non-null   object
#  3   Runtime     6190 non-null   object
#  4   Genre       6190 non-null   object
#  5   Director    6190 non-null   object
#  6   Writer      6190 non-null   object
#  7   Actors      6190 non-null   object
#  8   Plot        6190 non-null   object
#  9   Language    6190 non-null   object
#  10  Country     6190 non-null   object
#  11  Awards      6190 non-null   object
#  12  Poster      6190 non-null   object
#  13  Ratings     6190 non-null   object
#  14  imdbRating  6190 non-null   float64
#  15  imdbVotes   6190 non-null   int32
#  16  imdbID      6190 non-null   object
#  17  BoxOffice   6190 non-null   object
#  18  Status      6190 non-null   object
#  19  wr          6190 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(1), object(16)
# memory usage: 991.4+ KB

# %%
qualified = qualified.drop_duplicates('Title', ignore_index= True)

qualified.head(5)
# Out:
#                       Title       Year  Rated  Runtime  \
# 0              Breaking Bad        NaT  TV-MA   49 min
# 1  The Shawshank Redemption 1994-01-01      R  142 min
# 2          Band of Brothers 2001-01-01  TV-MA  594 min
# 3                 Chernobyl 2019-01-01  TV-MA  330 min
# 4           Game of Thrones        NaT  TV-MA   57 min
#
#                       Genre        Director                        Writer  \
# 0    Crime, Drama, Thriller         Unknown                Vince Gilligan
# 1                     Drama  Frank Darabont  Stephen King, Frank Darabont
# 2       Drama, History, War         Unknown                       Unknown
# 3  Drama, History, Thriller         Unknown                   Craig Mazin
# 4  Action, Adventure, Drama         Unknown     David Benioff, D.B. Weiss
#
#                                             Actors  \
# 0            Bryan Cranston, Aaron Paul, Anna Gunn
# 1          Tim Robbins, Morgan Freeman, Bob Gunton
# 2       Scott Grimes, Damian Lewis, Ron Livingston
# 3  Jessie Buckley, Jared Harris, Stellan Skarsgård
# 4     Emilia Clarke, Peter Dinklage, Kit Harington
#
#                                                 Plot  \
# 0  A chemistry teacher diagnosed with inoperable ...
# 1  A banker convicted of uxoricide forms a friend...
# 2  The story of Easy Company of the U.S. Army 101...
# 3  In April 1986, the city of Chernobyl in the So...
# 4  Nine noble families fight for control over the...
#
#                                      Language                        Country  \
# 0                            English, Spanish                  United States
# 1                                     English                  United States
# 2  English, Dutch, French, German, Lithuanian  United Kingdom, United States
# 3                 English, Russian, Ukrainian  United States, United Kingdom
# 4                                     English  United States, United Kingdom
#
#                                               Awards  \
# 0  Won 16 Primetime Emmys. 169 wins & 269 nominat...
# 1  Nominated for 7 Oscars. 21 wins & 42 nominatio...
# 2  Won 6 Primetime Emmys. 34 wins & 26 nomination...
# 3  Won 10 Primetime Emmys. 85 wins & 60 nominatio...
# 4  Won 59 Primetime Emmys. 397 wins & 655 nominat...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMzU5ZG...
# 1  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 2  https://m.media-amazon.com/images/M/MV5BMTQ3NT...
# 3  https://m.media-amazon.com/images/M/MV5BMmQ0Y2...
# 4  https://m.media-amazon.com/images/M/MV5BYzE5Mj...
#
#                                              Ratings  imdbRating  imdbVotes  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...         9.5    2225876
# 1  [{'Source': 'Internet Movie Database', 'Value'...         9.3    2945396
# 2  [{'Source': 'Internet Movie Database', 'Value'...         9.4     542582
# 3  [{'Source': 'Internet Movie Database', 'Value'...         9.3     902682
# 4  [{'Source': 'Internet Movie Database', 'Value'...         9.2    2359163
#
#       imdbID     BoxOffice    Status        wr
# 0  tt0903747       Unknown  Finished  9.465635
# 1  tt0111161  $28,767,189   Finished  9.275364
# 2  tt0185906       Unknown  Finished  9.266599
# 3  tt7366338       Unknown  Finished  9.220862
# 4  tt0944947       Unknown  Finished  9.170163

# %%
qualified.to_csv('../data/processed/movie_data_processed.csv', index= False)

# %%
tags_df = pd.read_csv('../data/raw/tags.csv', index_col=False)
links_df = pd.read_csv('../data/raw/links.csv', index_col=False)

# %%
tags_df.head(5)
# Out:
#    userId  movieId          tag
# 0      22    26479  Kevin Kline
# 1      22    79592     misogyny
# 2      22   247150   acrophobia
# 3      34     2174        music
# 4      34     2174        weird

# %%
links_df = links_df.drop("tmdbId", axis = 1)
links_df.head(5)
# Out:
#    movieId  imdbId
# 0        1  114709
# 1        2  113497
# 2        3  113228
# 3        4  114885
# 4        5  113041

# %%
merged_tags_df = tags_df.merge(links_df, on="movieId", how="inner")
merged_tags_df['imdbId'] = merged_tags_df['imdbId'].apply(lambda x: f'tt{str(x).zfill(7)}')
merged_tags_df.head(5)
# Out:
#    userId  movieId                 tag     imdbId
# 0      22    26479         Kevin Kline  tt0086112
# 1    9112    26479             musical  tt0086112
# 2   20627    26479        swashbuckler  tt0086112
# 3   36595    26479  Gilbert & Sullivan  tt0086112
# 4   36595    26479            operetta  tt0086112

# %%
merged_tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   userId   1048575 non-null  int64
#  1   movieId  1048575 non-null  int64
#  2   tag      1048574 non-null  object
#  3   imdbId   1048575 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 32.0+ MB

# %%
tags_df = merged_tags_df[merged_tags_df['imdbId'].isin(qualified['imdbID'])]
tags_df.head(5)
# Out:
#     userId  movieId            tag     imdbId
# 7       22    79592       misogyny  tt1386588
# 8      303    79592    buddy movie  tt1386588
# 9      303    79592          funny  tt1386588
# 10     303    79592  Mark Wahlberg  tt1386588
# 11     303    79592  New York City  tt1386588

# %%
tags_df.to_csv("../data/processed/tags_processed.csv", index= False)

# %%
ratings_df = pd.read_csv('../data/raw/ratings.csv', index_col=False)

# %%
ratings_df.dropna()
# Out:
#           userId  movieId  rating
# 0              1       17     8.0
# 1              1       25     2.0
# 2              1       29     4.0
# 3              1       30    10.0
# 4              1       32    10.0
# ...          ...      ...     ...
# 32000199  200948    79702     9.0
# 32000200  200948    79796     2.0
# 32000201  200948    80350     1.0
# 32000202  200948    80463     7.0
# 32000203  200948    87304     9.0
#
# [32000204 rows x 3 columns]

# %%
ratings_df.head(5)
# Out:
#    userId  movieId  rating
# 0       1       17     8.0
# 1       1       25     2.0
# 2       1       29     4.0
# 3       1       30    10.0
# 4       1       32    10.0

# %%
links_df = links_df.rename(columns= {'imdbId': 'imdbID'})

# %%
movie_rating_counts = ratings_df.groupby('movieId')['userId'].count()

popular_movies = movie_rating_counts[movie_rating_counts > 5000].index
del movie_rating_counts

df_ratings_filtered = ratings_df[ratings_df['movieId'].isin(popular_movies)]
del popular_movies

df_ratings_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21929272 entries, 0 to 32000202
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   userId   int64
#  1   movieId  int64
#  2   rating   float64
# dtypes: float64(1), int64(2)
# memory usage: 669.2 MB

# %%
start = 0
chunk_size = 1000000

merged_ratings_df = pd.DataFrame()

while True:
    chunk = df_ratings_filtered.iloc[start:start + chunk_size]

    if chunk.empty:
        break
    
    merged_ratings_df = merged_ratings_df._append(chunk.merge(links_df, on="movieId", how="inner"), ignore_index=True)
    
    start += chunk_size

results = []

for chunk in range(0, len(merged_ratings_df), chunk_size):
    merged_ratings_df_chunk = merged_ratings_df.iloc[chunk:chunk + chunk_size]
    result_chunk = merged_ratings_df_chunk['imdbID'].apply(lambda x: f'tt{str(x).zfill(7)}')
    results.append(result_chunk)

merged_ratings_df['imdbID'] = pd.concat(results)

merged_ratings_df.head(5)
# Out:
#    userId  movieId  rating     imdbID
# 0       1       17     8.0  tt0114388
# 1       3       17    10.0  tt0114388
# 2      15       17     9.0  tt0114388
# 3      28       17     8.0  tt0114388
# 4      29       17     8.0  tt0114388

# %%
ratings_df = merged_ratings_df[merged_ratings_df['imdbID'].isin(qualified['imdbID'])]
ratings_df = ratings_df.drop(columns='movieId')
ratings_df.head(5)
# Out:
#    userId  rating     imdbID
# 0       1     8.0  tt0114388
# 1       3    10.0  tt0114388
# 2      15     9.0  tt0114388
# 3      28     8.0  tt0114388
# 4      29     8.0  tt0114388

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21201140 entries, 0 to 21929271
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   userId  int64
#  1   rating  float64
#  2   imdbID  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 647.0+ MB

# %%
ratings_df.to_csv("../data/processed/ratings_processed.csv", index= False)
